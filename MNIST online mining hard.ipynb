# %%
import torch

from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision.transforms import Compose, ToTensor, Normalize

import numpy as np
from sklearn.datasets import make_blobs
from sklearn.manifold import TSNE

from TNN import Mining, Model
from TNN.Plot import scatter
from TNN.Loss_Fn import triplet_loss

# %%
device = torch.device('cuda:2')
tsne = TSNE(random_state=0)
batch_size_train = 16 # When the batch size is too huge the model collapse, but why?
vis_batch_size_train = 256

# %%
train_loader = DataLoader(MNIST('./MNIST/', train=True, download=True,
                                transform=Compose([ToTensor(),Normalize((0.1307,), (0.3081,))])
                               ),batch_size=vis_batch_size_train, shuffle=True)
test_loader = DataLoader(MNIST('./MNIST/', train=False, download=True,
                                transform=Compose([ToTensor(),Normalize((0.1307,), (0.3081,))])
                               ),batch_size=vis_batch_size_train, shuffle=False)

# %%
x_test, y_test = next(iter(test_loader))
x_test = x_test.to(device)
y_test = y_test.to(device)

# %%
x_train, y_train = next(iter(train_loader))
x_train = x_train.to(device)
y_train = y_train.to(device)

# %%
train_loader = DataLoader(MNIST('./MNIST/', train=True, download=True,
                                transform=Compose([ToTensor(),Normalize((0.1307,), (0.3081,))])
                               ),batch_size=batch_size_train, shuffle=True)
test_loader = DataLoader(MNIST('./MNIST/', train=False, download=True,
                                transform=Compose([ToTensor(),Normalize((0.1307,), (0.3081,))])
                               ),batch_size=batch_size_train, shuffle=False)

# %%
train_tsne_embeds = tsne.fit_transform(x_train.flatten(1).cpu().detach().numpy())
test_tsne_embeds = tsne.fit_transform(x_test.flatten(1).cpu().detach().numpy())

scatter(train_tsne_embeds, y_train.cpu().numpy(), f'Original MNIST distribution (train set)')
scatter(test_tsne_embeds, y_test.cpu().numpy(), f'Original MNIST distribution (test set)')

# %%
model = Model.TNN()
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
for epoch in range(100):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        # get the inputs
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        loss, pos_mask, neg_mask = Mining.online_mine_hard(labels, outputs, margin=0.4, squared=True, device=device)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        if i%2 == 0:
            print(f"At epoches = {epoch}, i = {i}, loss = {loss:.5f}, pos_mask = {pos_mask}, neg_mask = {neg_mask}"
                  , end='\r')
    epoch_loss = running_loss / len(train_loader)
    
    print(" "*100)
    print(f"At epoches = {epoch}, epoch_loss = {epoch_loss}")
print('Finished Training')
# Out:
#
# At epoches = 0, epoch_loss = 0.1322643405124545
#
# At epoches = 1, epoch_loss = 0.05817100468426943
#
# At epoches = 2, epoch_loss = 0.042646318834026656
#
# At epoches = 3, epoch_loss = 0.03384141025195519
#
# At epoches = 4, epoch_loss = 0.027054885804653168
#
# At epoches = 5, epoch_loss = 0.024132526753346126
#
# At epoches = 6, epoch_loss = 0.02039296377549569
#
# At epoches = 7, epoch_loss = 0.017265045219659804
#
# At epoches = 8, epoch_loss = 0.016035632083316643
#
# At epoches = 9, epoch_loss = 0.014171677888929844
#
# At epoches = 10, epoch_loss = 0.012255262513955435
#
# At epoches = 11, epoch_loss = 0.010911882770061493
#
# At epoches = 12, epoch_loss = 0.009542185876766841
#
# At epoches = 13, epoch_loss = 0.00907023951758941
#
# At epoches = 14, epoch_loss = 0.008249052619934081
#
# At epoches = 15, epoch_loss = 0.007444140849510829
#
# At epoches = 16, epoch_loss = 0.007884853527446587
#
# At epoches = 17, epoch_loss = 0.0066837066079179445
#
# At epoches = 18, epoch_loss = 0.006905784526467324
#
# At epoches = 19, epoch_loss = 0.005655398843685786
#
# At epoches = 20, epoch_loss = 0.005736600803832213
#
# At epoches = 21, epoch_loss = 0.005109768159190814
#
# At epoches = 22, epoch_loss = 0.005408068658411503
#
# At epoches = 23, epoch_loss = 0.004779309883217017
#
# At epoches = 24, epoch_loss = 0.004457938882211844
#
# At epoches = 25, epoch_loss = 0.004427764012912909
#
# At epoches = 26, epoch_loss = 0.004144522685805957
#
# At epoches = 27, epoch_loss = 0.004153282648324966
#
# At epoches = 28, epoch_loss = 0.0038204079439242682
#
# At epoches = 29, epoch_loss = 0.003955168340603511
#
# At epoches = 30, epoch_loss = 0.0042411280905207
#
# At epoches = 31, epoch_loss = 0.003909405414263408
#
# At epoches = 32, epoch_loss = 0.0033204393883546194
#
# At epoches = 33, epoch_loss = 0.0033069509978095693
#
# At epoches = 34, epoch_loss = 0.0034919744248191518
#
# At epoches = 35, epoch_loss = 0.0029567514782150588
#
# At epoches = 36, epoch_loss = 0.0032028528104225793
#
# At epoches = 37, epoch_loss = 0.002916752814749877
#
# At epoches = 38, epoch_loss = 0.003143936432401339
#
# At epoches = 39, epoch_loss = 0.00315654114484787
#
# At epoches = 40, epoch_loss = 0.0029094487542907395
#
# At epoches = 41, epoch_loss = 0.0024787305946151416
#
# At epoches = 42, epoch_loss = 0.0027641439840197565
#
# At epoches = 43, epoch_loss = 0.0025928933839003245
#
# At epoches = 44, epoch_loss = 0.0025129506319761276
#
# At epoches = 45, epoch_loss = 0.0030841407204667726
#
# At epoches = 46, epoch_loss = 0.00229997776945432
#
# At epoches = 47, epoch_loss = 0.002769295529524485
#
# At epoches = 48, epoch_loss = 0.0021111121088266374
#
# At epoches = 49, epoch_loss = 0.002466869369149208
#
# At epoches = 50, epoch_loss = 0.0025627018983165424
#
# At epoches = 51, epoch_loss = 0.0024871355811754863
#
# At epoches = 52, epoch_loss = 0.0026577832917372385
#
# At epoches = 53, epoch_loss = 0.0024260287284851075
#
# At epoches = 54, epoch_loss = 0.0023821007564663885
#
# At epoches = 55, epoch_loss = 0.0021320469066500665
#
# At epoches = 56, epoch_loss = 0.002365485216677189
#
# At epoches = 57, epoch_loss = 0.0025014364808797836
#
# At epoches = 58, epoch_loss = 0.002179880497356256
#
# At epoches = 59, epoch_loss = 0.0024281862616539
#
# At epoches = 60, epoch_loss = 0.002316216732064883
#
# At epoches = 61, epoch_loss = 0.002151043942073981
#
# At epoches = 62, epoch_loss = 0.0018791529178619384
#
# At epoches = 63, epoch_loss = 0.0025160191883643467
#
# At epoches = 64, epoch_loss = 0.002143669350941976
#
# At epoches = 65, epoch_loss = 0.002550809967517853
#
# At epoches = 66, epoch_loss = 0.0022128834878404934
#
# At epoches = 67, epoch_loss = 0.0022696883926788965
#
# At epoches = 68, epoch_loss = 0.0018880146155754725
#
# At epoches = 69, epoch_loss = 0.0022056356777747474
#
# At epoches = 70, epoch_loss = 0.0016499721705913544
#
# At epoches = 71, epoch_loss = 0.0018822327464818954
#
# At epoches = 72, epoch_loss = 0.0021415996382633845
#
# At epoches = 73, epoch_loss = 0.0019898991331458093
#
# At epoches = 74, epoch_loss = 0.002362733407318592
#
# At epoches = 75, epoch_loss = 0.002116140183309714
#
# At epoches = 76, epoch_loss = 0.0018883939986427626
#
# At epoches = 77, epoch_loss = 0.002289181490242481
#
# At epoches = 78, epoch_loss = 0.001994626625378927
#
# At epoches = 79, epoch_loss = 0.002228306756913662
#
# At epoches = 80, epoch_loss = 0.0015938033252954483
#
# At epoches = 81, epoch_loss = 0.0019735880146423976
#
# At epoches = 82, epoch_loss = 0.00189186949133873
#
# At epoches = 83, epoch_loss = 0.001766405323644479
#
# At epoches = 84, epoch_loss = 0.0017843492314219475
#
# At epoches = 85, epoch_loss = 0.0022805062169830004
#
# At epoches = 86, epoch_loss = 0.0014042468825976053
#
# At epoches = 87, epoch_loss = 0.0022384409308433533
#
# At epoches = 88, epoch_loss = 0.0016783005326986313
#
# At epoches = 89, epoch_loss = 0.001899948239326477
#
# At epoches = 90, epoch_loss = 0.0017680045922597249
#
# At epoches = 91, epoch_loss = 0.0021403810118635494
#
# At epoches = 92, epoch_loss = 0.001692337627708912
#
# At epoches = 93, epoch_loss = 0.001889443999528885
#
# At epoches = 94, epoch_loss = 0.0025277946561574937
#
# At epoches = 95, epoch_loss = 0.001667270772655805
#
# At epoches = 96, epoch_loss = 0.0018840677494804065
#
# At epoches = 97, epoch_loss = 0.0019454059208432832
#
# At epoches = 98, epoch_loss = 0.0015972599923610687
#
# At epoches = 99, epoch_loss = 0.0016524580672383309
# Finished Training

# %%
train_outputs = model(x_train)
test_outputs = model(x_test)
train_tsne_embeds = tsne.fit_transform(train_outputs.cpu().detach().numpy())
test_tsne_embeds = tsne.fit_transform(test_outputs.cpu().detach().numpy())

scatter(train_tsne_embeds, y_train.cpu().numpy(), f'TNN distribution (train set)')
scatter(test_tsne_embeds, y_test.cpu().numpy(), f'TNN distribution (test set)')
