# %%
import torch

from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision.transforms import Compose, ToTensor, Normalize

import numpy as np
from sklearn.datasets import make_blobs
from sklearn.manifold import TSNE

from TNN import Mining, Model
from TNN.Plot import scatter
from TNN.Loss_Fn import triplet_loss

# %%
device = torch.device('cuda:0')
tsne = TSNE(random_state=0)
batch_size_train = 16 # When the batch size is too huge the model collapse, but why?
vis_batch_size_train = 256

# %%
train_loader = DataLoader(MNIST('./MNIST/', train=True, download=True,
                                transform=Compose([ToTensor(),Normalize((0.1307,), (0.3081,))])
                               ),batch_size=vis_batch_size_train, shuffle=True)
test_loader = DataLoader(MNIST('./MNIST/', train=False, download=True,
                                transform=Compose([ToTensor(),Normalize((0.1307,), (0.3081,))])
                               ),batch_size=vis_batch_size_train, shuffle=False)

# %%
x_test, y_test = next(iter(test_loader))
x_test = x_test.to(device)
y_test = y_test.to(device)

# %%
x_train, y_train = next(iter(train_loader))
x_train = x_train.to(device)
y_train = y_train.to(device)

# %%
train_loader = DataLoader(MNIST('./MNIST/', train=True, download=True,
                                transform=Compose([ToTensor(),Normalize((0.1307,), (0.3081,))])
                               ),batch_size=batch_size_train, shuffle=True)
test_loader = DataLoader(MNIST('./MNIST/', train=False, download=True,
                                transform=Compose([ToTensor(),Normalize((0.1307,), (0.3081,))])
                               ),batch_size=batch_size_train, shuffle=False)

# %%
train_tsne_embeds = tsne.fit_transform(x_train.flatten(1).cpu().detach().numpy())
test_tsne_embeds = tsne.fit_transform(x_test.flatten(1).cpu().detach().numpy())

scatter(train_tsne_embeds, y_train.cpu().numpy(), subtitle=f'online hard Original MNIST distribution (train set)')
scatter(test_tsne_embeds, y_test.cpu().numpy(), subtitle=f'online hard Original MNIST distribution (test set)')

# %%
model = Model.TNN(input_shape=x_train.shape[1:])
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
margin=0.4
for epoch in range(100):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        # get the inputs
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        loss, pos_mask, neg_mask = Mining.online_mine_hard(labels, outputs, margin=margin, squared=True, device=device)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        if i%2 == 0:
            print(f"At epoches = {epoch}, i = {i}, loss = {loss:.5f}, pos_mask = {pos_mask}, neg_mask = {neg_mask}"
                  , end='\r')
    epoch_loss = running_loss / len(train_loader)
    
    print(" "*100)
    print(f"At epoches = {epoch}, epoch_loss = {epoch_loss}")
print('Finished Training')
# Out:
#
# At epoches = 0, epoch_loss = 0.13150761972367764
#
# At epoches = 1, epoch_loss = 0.06014770845323801
#
# At epoches = 2, epoch_loss = 0.04250067058304945
#
# At epoches = 3, epoch_loss = 0.0342122053399682
#
# At epoches = 4, epoch_loss = 0.02796637425770362
#
# At epoches = 5, epoch_loss = 0.02331166821718216
#
# At epoches = 6, epoch_loss = 0.02005737500389417
#
# At epoches = 7, epoch_loss = 0.0174687094271183
#
# At epoches = 8, epoch_loss = 0.015460782936215401
#
# At epoches = 9, epoch_loss = 0.014079770881930987
#
# At epoches = 10, epoch_loss = 0.012297824976841608
#
# At epoches = 11, epoch_loss = 0.011292479032774767
#
# At epoches = 12, epoch_loss = 0.010805146157244842
#
# At epoches = 13, epoch_loss = 0.008349491700530053
#
# At epoches = 14, epoch_loss = 0.008985928465425968
#
# At epoches = 15, epoch_loss = 0.007673208068311214
#
# At epoches = 16, epoch_loss = 0.007326247561971346
#
# At epoches = 17, epoch_loss = 0.00674407497048378
#
# At epoches = 18, epoch_loss = 0.0063959553117553395
#
# At epoches = 19, epoch_loss = 0.005845200057327748
#
# At epoches = 20, epoch_loss = 0.0060999840304255485
#
# At epoches = 21, epoch_loss = 0.004647642429669698
#
# At epoches = 22, epoch_loss = 0.0052018710513909655
#
# At epoches = 23, epoch_loss = 0.004571101835370064
#
# At epoches = 24, epoch_loss = 0.004926462149123351
#
# At epoches = 25, epoch_loss = 0.0042367943987250325
#
# At epoches = 26, epoch_loss = 0.004694501131772995
#
# At epoches = 27, epoch_loss = 0.003912615438302358
#
# At epoches = 28, epoch_loss = 0.00349143954962492
#
# At epoches = 29, epoch_loss = 0.003727601000169913
#
# At epoches = 30, epoch_loss = 0.0038314984182516733
#
# At epoches = 31, epoch_loss = 0.003315226423740387
#
# At epoches = 32, epoch_loss = 0.003402788875500361
#
# At epoches = 33, epoch_loss = 0.0033966449305415152
#
# At epoches = 34, epoch_loss = 0.0033424642354249953
#
# At epoches = 35, epoch_loss = 0.0035142947246630985
#
# At epoches = 36, epoch_loss = 0.0032408997416496278
#
# At epoches = 37, epoch_loss = 0.0031995315944155058
#
# At epoches = 38, epoch_loss = 0.0032699167216817537
#
# At epoches = 39, epoch_loss = 0.002646111340820789
#
# At epoches = 40, epoch_loss = 0.003258066382507483
#
# At epoches = 41, epoch_loss = 0.0028129178206125894
#
# At epoches = 42, epoch_loss = 0.0025193940485517185
#
# At epoches = 43, epoch_loss = 0.002549996806681156
#
# At epoches = 44, epoch_loss = 0.002841864639520645
#
# At epoches = 45, epoch_loss = 0.0027232580373684565
#
# At epoches = 46, epoch_loss = 0.0021495705862840018
#
# At epoches = 47, epoch_loss = 0.002735560930768649
#
# At epoches = 48, epoch_loss = 0.0024389928221702577
#
# At epoches = 49, epoch_loss = 0.0022173742815852163
#
# At epoches = 50, epoch_loss = 0.0030195515498518946
#
# At epoches = 51, epoch_loss = 0.0025193693319956463
#
# At epoches = 52, epoch_loss = 0.0022643498688936234
#
# At epoches = 53, epoch_loss = 0.002493929223716259
#
# At epoches = 54, epoch_loss = 0.002687558719019095
#
# At epoches = 55, epoch_loss = 0.002520325355231762
#
# At epoches = 56, epoch_loss = 0.0024172497779130935
#
# At epoches = 57, epoch_loss = 0.0021726181348164877
#
# At epoches = 58, epoch_loss = 0.0021419509306550024
#
# At epoches = 59, epoch_loss = 0.002474796679119269
#
# At epoches = 60, epoch_loss = 0.002427577356994152
#
# At epoches = 61, epoch_loss = 0.0026802264307936034
#
# At epoches = 62, epoch_loss = 0.0016309218888481457
#
# At epoches = 63, epoch_loss = 0.002048516203959783
#
# At epoches = 64, epoch_loss = 0.002156214069823424
#
# At epoches = 65, epoch_loss = 0.0023489864925543467
#
# At epoches = 66, epoch_loss = 0.0020293884937961897
#
# At epoches = 67, epoch_loss = 0.002448229184250037
#
# At epoches = 68, epoch_loss = 0.0021060351913173994
#
# At epoches = 69, epoch_loss = 0.0021173510745167733
#
# At epoches = 70, epoch_loss = 0.0021674401024977365
#
# At epoches = 71, epoch_loss = 0.001855631219347318
#
# At epoches = 72, epoch_loss = 0.0020319442848364512
#
# At epoches = 73, epoch_loss = 0.0017995401268204054
#
# At epoches = 74, epoch_loss = 0.002394268389046192
#
# At epoches = 75, epoch_loss = 0.0022157696083188057
#
# At epoches = 76, epoch_loss = 0.00219330840408802
#
# At epoches = 77, epoch_loss = 0.0017122459689776102
#
# At epoches = 78, epoch_loss = 0.002297808553278446
#
# At epoches = 79, epoch_loss = 0.0018662569498022398
#
# At epoches = 80, epoch_loss = 0.0017473783537745476
#
# At epoches = 81, epoch_loss = 0.002090565426647663
#
# At epoches = 82, epoch_loss = 0.002615744394560655
#
# At epoches = 83, epoch_loss = 0.0015307976186275483
#
# At epoches = 84, epoch_loss = 0.0018544699942072234
#
# At epoches = 85, epoch_loss = 0.0020605580935875575
#
# At epoches = 86, epoch_loss = 0.0017636546070377032
#
# At epoches = 87, epoch_loss = 0.0018743888144691786
#
# At epoches = 88, epoch_loss = 0.0017582553615172703
#
# At epoches = 89, epoch_loss = 0.0018848349079489707
#
# At epoches = 90, epoch_loss = 0.0019332153181234996
#
# At epoches = 91, epoch_loss = 0.0022070193295677504
#
# At epoches = 92, epoch_loss = 0.002062091432015101
#
# At epoches = 93, epoch_loss = 0.0017980298260847727
#
# At epoches = 94, epoch_loss = 0.0021220526213447254
#
# At epoches = 95, epoch_loss = 0.0022099554722507793
#
# At epoches = 96, epoch_loss = 0.0015044251849253973
#
# At epoches = 97, epoch_loss = 0.001875171200434367
#
# At epoches = 98, epoch_loss = 0.0014936318576335907
#
# At epoches = 99, epoch_loss = 0.001842839090526104
# Finished Training

# %%
train_outputs = model(x_train)
test_outputs = model(x_test)
train_tsne_embeds = tsne.fit_transform(train_outputs.cpu().detach().numpy())
test_tsne_embeds = tsne.fit_transform(test_outputs.cpu().detach().numpy())

scatter(train_tsne_embeds, y_train.cpu().numpy(), subtitle=f'online hard TNN distribution (train set)')
scatter(test_tsne_embeds, y_test.cpu().numpy(), subtitle=f'online hard TNN distribution (test set)')
