# %%
import torch

from torch.utils.data import DataLoader
from torchvision.datasets import CIFAR10, MNIST
from torchvision.transforms import Compose, ToTensor, Normalize

import numpy as np
from sklearn.datasets import make_blobs
from sklearn.manifold import TSNE

from TNN import Mining, Model
from TNN.Plot import scatter
from TNN.Loss_Fn import triplet_loss

# %%
device = torch.device('cuda:1')
tsne = TSNE(random_state=0)
batch_size_train = 256

# %%
train_loader = DataLoader(CIFAR10('./CIFAR10/', train=True, download=True,
                                transform=Compose([ToTensor(),Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
                               ),batch_size=batch_size_train, shuffle=True)
test_loader = DataLoader(CIFAR10('./CIFAR10/', train=False, download=True,
                                transform=Compose([ToTensor(),Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
                               ),batch_size=batch_size_train, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
x_test, y_test = next(iter(test_loader))
x_test = x_test.to(device)
y_test = y_test.to(device)

# %%
x_train, y_train = next(iter(train_loader))
x_train = x_train.to(device)
y_train = y_train.to(device)

# %%
train_tsne_embeds = tsne.fit_transform(x_train.flatten(1).cpu().detach().numpy())
test_tsne_embeds = tsne.fit_transform(x_test.flatten(1).cpu().detach().numpy())

# %%
scatter(train_tsne_embeds, y_train.cpu().numpy(), subtitle=f'online Original MNIST distribution (train set)', dataset='CIFAR10')
scatter(test_tsne_embeds, y_test.cpu().numpy(), subtitle=f'online Original MNIST distribution (test set)', dataset='CIFAR10')

# %%
model = Model.SimpleTNN(input_shape=x_train.shape[1:], output_size=128)
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

# %%
margin = 0.5
for epoch in range(300):  # loop over the dataset multiple times

    running_loss = 0.0
    model.train()
    for i, data in enumerate(train_loader, 0):
        # get the inputs
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        loss, pos_triplet, valid_triplet = Mining.online_mine_all(labels, outputs, margin=margin, squared=True, device=device)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        if i%2 == 0:
            print(f"At epoches = {epoch}, i = {i}, loss = {loss:.5f}, trainable_triplet = {pos_triplet}, total_triplets = {valid_triplet}"
                  , end='\r')
    train_epoch_loss = running_loss / len(train_loader)

    # Evaluating on test set
    print(" "*100)
    running_loss = 0.0
    model.eval()
    for i, data in enumerate(test_loader, 0):
        # get the inputs
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        loss, pos_triplet, valid_triplet = Mining.online_mine_all(labels, outputs, margin=margin, squared=True, device=device)
        running_loss += loss.item()
        if i%2 == 0:
            print(f"Evaluating At epoches = {epoch}, i = {i}, loss = {loss:.5f}", end='\r')
    test_epoch_loss = running_loss / len(test_loader)
    
    print(" "*100)
    print(f"At epoches = {epoch}, epoch_train_loss = {train_epoch_loss:.6f},\tepoch_test_loss = {test_epoch_loss:.6f}")
print('Finished Training')
# Out:
#
#
# At epoches = 0, epoch_train_loss = 3.331965,	epoch_test_loss = 2.110645
#
#
# At epoches = 1, epoch_train_loss = 1.814860,	epoch_test_loss = 1.577864
#
#
# At epoches = 2, epoch_train_loss = 1.442364,	epoch_test_loss = 1.312990
#
#
# At epoches = 3, epoch_train_loss = 1.237791,	epoch_test_loss = 1.153689
#
#
# At epoches = 4, epoch_train_loss = 1.107836,	epoch_test_loss = 1.057687
#
#
# At epoches = 5, epoch_train_loss = 1.014497,	epoch_test_loss = 0.981351
#
#
# At epoches = 6, epoch_train_loss = 0.944645,	epoch_test_loss = 0.915903
#
#
# At epoches = 7, epoch_train_loss = 0.886272,	epoch_test_loss = 0.863060
#
#
# At epoches = 8, epoch_train_loss = 0.842743,	epoch_test_loss = 0.822684
#
#
# At epoches = 9, epoch_train_loss = 0.805115,	epoch_test_loss = 0.790824
#
#
# At epoches = 10, epoch_train_loss = 0.773840,	epoch_test_loss = 0.759977
#
#
# At epoches = 11, epoch_train_loss = 0.747342,	epoch_test_loss = 0.741955
#
#
# At epoches = 12, epoch_train_loss = 0.724893,	epoch_test_loss = 0.722497
#
#
# At epoches = 13, epoch_train_loss = 0.705453,	epoch_test_loss = 0.701592
#
#
# At epoches = 14, epoch_train_loss = 0.688173,	epoch_test_loss = 0.692679
#
#
# At epoches = 15, epoch_train_loss = 0.673266,	epoch_test_loss = 0.686047
#
#
# At epoches = 16, epoch_train_loss = 0.659984,	epoch_test_loss = 0.655748
#
#
# At epoches = 17, epoch_train_loss = 0.648282,	epoch_test_loss = 0.651200
#
#
# At epoches = 18, epoch_train_loss = 0.637725,	epoch_test_loss = 0.651787
#
#
# At epoches = 19, epoch_train_loss = 0.629675,	epoch_test_loss = 0.629973
#
#
# At epoches = 20, epoch_train_loss = 0.620057,	epoch_test_loss = 0.623811
#
#
# At epoches = 21, epoch_train_loss = 0.612607,	epoch_test_loss = 0.617192
#
#
# At epoches = 22, epoch_train_loss = 0.605739,	epoch_test_loss = 0.611548
#
#
# At epoches = 23, epoch_train_loss = 0.599606,	epoch_test_loss = 0.615981
#
#
# At epoches = 24, epoch_train_loss = 0.594132,	epoch_test_loss = 0.602696
#
#
# At epoches = 25, epoch_train_loss = 0.588476,	epoch_test_loss = 0.606212
#
#
# At epoches = 26, epoch_train_loss = 0.585309,	epoch_test_loss = 0.587823
#
#
# At epoches = 27, epoch_train_loss = 0.580076,	epoch_test_loss = 0.579016
#
#
# At epoches = 28, epoch_train_loss = 0.575259,	epoch_test_loss = 0.590996
#
#
# At epoches = 29, epoch_train_loss = 0.573402,	epoch_test_loss = 0.583995
#
#
# At epoches = 30, epoch_train_loss = 0.570570,	epoch_test_loss = 0.578807
#
#
# At epoches = 31, epoch_train_loss = 0.566538,	epoch_test_loss = 0.565163
#
#
# At epoches = 32, epoch_train_loss = 0.563691,	epoch_test_loss = 0.565873
#
#
# At epoches = 33, epoch_train_loss = 0.560983,	epoch_test_loss = 0.574160
#
#
# At epoches = 34, epoch_train_loss = 0.558572,	epoch_test_loss = 0.575595
#
#
# At epoches = 35, epoch_train_loss = 0.556111,	epoch_test_loss = 0.573842
#
#
# At epoches = 36, epoch_train_loss = 0.555050,	epoch_test_loss = 0.560104
#
#
# At epoches = 37, epoch_train_loss = 0.552529,	epoch_test_loss = 0.567148
#
#
# At epoches = 38, epoch_train_loss = 0.550956,	epoch_test_loss = 0.561284
#
#
# At epoches = 39, epoch_train_loss = 0.549398,	epoch_test_loss = 0.561733
#
#
# At epoches = 40, epoch_train_loss = 0.547767,	epoch_test_loss = 0.561155
#
#
# At epoches = 41, epoch_train_loss = 0.546583,	epoch_test_loss = 0.559365
#
#
# At epoches = 42, epoch_train_loss = 0.543643,	epoch_test_loss = 0.561603
#
#
# At epoches = 43, epoch_train_loss = 0.543459,	epoch_test_loss = 0.555239
#
#
# At epoches = 44, epoch_train_loss = 0.542062,	epoch_test_loss = 0.552461
#
#
# At epoches = 45, epoch_train_loss = 0.541240,	epoch_test_loss = 0.559398
#
#
# At epoches = 46, epoch_train_loss = 0.539016,	epoch_test_loss = 0.559483
#
#
# At epoches = 47, epoch_train_loss = 0.538542,	epoch_test_loss = 0.552784
#
#
# At epoches = 48, epoch_train_loss = 0.538376,	epoch_test_loss = 0.545028
#
#
# At epoches = 49, epoch_train_loss = 0.536577,	epoch_test_loss = 0.549010
#
#
# At epoches = 50, epoch_train_loss = 0.535522,	epoch_test_loss = 0.552062
#
#
# At epoches = 51, epoch_train_loss = 0.535316,	epoch_test_loss = 0.547304
#
#
# At epoches = 52, epoch_train_loss = 0.533975,	epoch_test_loss = 0.540644
#
#
# At epoches = 53, epoch_train_loss = 0.533604,	epoch_test_loss = 0.552532
#
#
# At epoches = 54, epoch_train_loss = 0.532253,	epoch_test_loss = 0.548144
#
#
# At epoches = 55, epoch_train_loss = 0.532062,	epoch_test_loss = 0.546241
#
#
# At epoches = 56, epoch_train_loss = 0.530880,	epoch_test_loss = 0.552633
#
#
# At epoches = 57, epoch_train_loss = 0.530535,	epoch_test_loss = 0.544138
#
#
# At epoches = 58, epoch_train_loss = 0.529771,	epoch_test_loss = 0.542920
#
#
# At epoches = 59, epoch_train_loss = 0.529125,	epoch_test_loss = 0.546396
#
#
# At epoches = 60, epoch_train_loss = 0.528924,	epoch_test_loss = 0.538606
#
#
# At epoches = 61, epoch_train_loss = 0.528944,	epoch_test_loss = 0.535607
#
#
# At epoches = 62, epoch_train_loss = 0.527127,	epoch_test_loss = 0.540093
#
#
# At epoches = 63, epoch_train_loss = 0.526711,	epoch_test_loss = 0.537928
#
#
# At epoches = 64, epoch_train_loss = 0.526436,	epoch_test_loss = 0.536509
#
#
# At epoches = 65, epoch_train_loss = 0.526322,	epoch_test_loss = 0.534943
#
#
# At epoches = 66, epoch_train_loss = 0.526084,	epoch_test_loss = 0.535098
#
#
# At epoches = 67, epoch_train_loss = 0.524912,	epoch_test_loss = 0.545143
#
#
# At epoches = 68, epoch_train_loss = 0.524520,	epoch_test_loss = 0.541031
#
#
# At epoches = 69, epoch_train_loss = 0.524375,	epoch_test_loss = 0.545138
#
#
# At epoches = 70, epoch_train_loss = 0.523750,	epoch_test_loss = 0.537023
#
#
# At epoches = 71, epoch_train_loss = 0.524218,	epoch_test_loss = 0.529984
#
#
# At epoches = 72, epoch_train_loss = 0.523517,	epoch_test_loss = 0.525170
#
#
# At epoches = 73, epoch_train_loss = 0.522665,	epoch_test_loss = 0.532138
#
#
# At epoches = 74, epoch_train_loss = 0.523176,	epoch_test_loss = 0.528946
#
#
# At epoches = 75, epoch_train_loss = 0.521609,	epoch_test_loss = 0.536613
#
#
# At epoches = 76, epoch_train_loss = 0.521475,	epoch_test_loss = 0.544843
#
#
# At epoches = 77, epoch_train_loss = 0.521489,	epoch_test_loss = 0.531573
#
#
# At epoches = 78, epoch_train_loss = 0.520919,	epoch_test_loss = 0.535973
#
#
# At epoches = 79, epoch_train_loss = 0.520808,	epoch_test_loss = 0.540965
#
#
# At epoches = 80, epoch_train_loss = 0.520724,	epoch_test_loss = 0.538932
#
#
# At epoches = 81, epoch_train_loss = 0.520798,	epoch_test_loss = 0.541128
#
#
# At epoches = 82, epoch_train_loss = 0.520369,	epoch_test_loss = 0.542167
#
#
# At epoches = 83, epoch_train_loss = 0.520288,	epoch_test_loss = 0.536068
#
#
# At epoches = 84, epoch_train_loss = 0.519599,	epoch_test_loss = 0.532550
#
#
# At epoches = 85, epoch_train_loss = 0.518883,	epoch_test_loss = 0.530804
#
#
# At epoches = 86, epoch_train_loss = 0.519830,	epoch_test_loss = 0.538755
#
#
# At epoches = 87, epoch_train_loss = 0.518481,	epoch_test_loss = 0.538166
#
#
# At epoches = 88, epoch_train_loss = 0.518787,	epoch_test_loss = 0.536747
#
#
# At epoches = 89, epoch_train_loss = 0.517271,	epoch_test_loss = 0.539967
#
#
# At epoches = 90, epoch_train_loss = 0.519415,	epoch_test_loss = 0.533629
#
#
# At epoches = 91, epoch_train_loss = 0.517814,	epoch_test_loss = 0.520550
#
#
# At epoches = 92, epoch_train_loss = 0.517137,	epoch_test_loss = 0.538841
#
#
# At epoches = 93, epoch_train_loss = 0.517654,	epoch_test_loss = 0.538023
#
#
# At epoches = 94, epoch_train_loss = 0.517677,	epoch_test_loss = 0.527715
#
#
# At epoches = 95, epoch_train_loss = 0.516999,	epoch_test_loss = 0.525294
#
#
# At epoches = 96, epoch_train_loss = 0.516696,	epoch_test_loss = 0.528911
#
#
# At epoches = 97, epoch_train_loss = 0.517045,	epoch_test_loss = 0.525628
#
#
# At epoches = 98, epoch_train_loss = 0.516796,	epoch_test_loss = 0.533939
#
#
# At epoches = 99, epoch_train_loss = 0.515961,	epoch_test_loss = 0.526762
#
#
# At epoches = 100, epoch_train_loss = 0.516389,	epoch_test_loss = 0.544155
#
#
# At epoches = 101, epoch_train_loss = 0.516763,	epoch_test_loss = 0.534033
#
#
# At epoches = 102, epoch_train_loss = 0.515601,	epoch_test_loss = 0.540880
#
#
# At epoches = 103, epoch_train_loss = 0.516197,	epoch_test_loss = 0.538549
#
#
# At epoches = 104, epoch_train_loss = 0.516089,	epoch_test_loss = 0.537470
#
#
# At epoches = 105, epoch_train_loss = 0.514838,	epoch_test_loss = 0.536469
#
#
# At epoches = 106, epoch_train_loss = 0.515123,	epoch_test_loss = 0.532220
#
#
# At epoches = 107, epoch_train_loss = 0.515520,	epoch_test_loss = 0.537349
#
#
# At epoches = 108, epoch_train_loss = 0.514828,	epoch_test_loss = 0.532598
#
#
# At epoches = 109, epoch_train_loss = 0.514761,	epoch_test_loss = 0.542038
#
#
# At epoches = 110, epoch_train_loss = 0.515109,	epoch_test_loss = 0.523305
#
#
# At epoches = 111, epoch_train_loss = 0.513660,	epoch_test_loss = 0.530756
#
#
# At epoches = 112, epoch_train_loss = 0.514097,	epoch_test_loss = 0.537788
#
#
# At epoches = 113, epoch_train_loss = 0.514862,	epoch_test_loss = 0.521589
#
#
# At epoches = 114, epoch_train_loss = 0.513925,	epoch_test_loss = 0.529309
#
#
# At epoches = 115, epoch_train_loss = 0.513675,	epoch_test_loss = 0.528170
#
#
# At epoches = 116, epoch_train_loss = 0.514213,	epoch_test_loss = 0.524081
#
#
# At epoches = 117, epoch_train_loss = 0.513113,	epoch_test_loss = 0.535512
#
#
# At epoches = 118, epoch_train_loss = 0.513963,	epoch_test_loss = 0.537766
#
#
# At epoches = 119, epoch_train_loss = 0.513515,	epoch_test_loss = 0.539517
#
#
# At epoches = 120, epoch_train_loss = 0.514339,	epoch_test_loss = 0.539958
#
#
# At epoches = 121, epoch_train_loss = 0.513585,	epoch_test_loss = 0.545401
#
#
# At epoches = 122, epoch_train_loss = 0.513142,	epoch_test_loss = 0.524727
#
#
# At epoches = 123, epoch_train_loss = 0.512275,	epoch_test_loss = 0.537178
#
#
# At epoches = 124, epoch_train_loss = 0.512540,	epoch_test_loss = 0.538308
#
#
# At epoches = 125, epoch_train_loss = 0.513037,	epoch_test_loss = 0.529039
#
#
# At epoches = 126, epoch_train_loss = 0.512798,	epoch_test_loss = 0.527646
#
#
# At epoches = 127, epoch_train_loss = 0.512198,	epoch_test_loss = 0.532981
#
#
# At epoches = 128, epoch_train_loss = 0.512543,	epoch_test_loss = 0.531256
#
#
# At epoches = 129, epoch_train_loss = 0.512968,	epoch_test_loss = 0.533322
#
#
# At epoches = 130, epoch_train_loss = 0.512485,	epoch_test_loss = 0.526443
#
#
# At epoches = 131, epoch_train_loss = 0.511747,	epoch_test_loss = 0.528482
#
#
# At epoches = 132, epoch_train_loss = 0.511978,	epoch_test_loss = 0.544924
#
#
# At epoches = 133, epoch_train_loss = 0.512114,	epoch_test_loss = 0.535458
#
#
# At epoches = 134, epoch_train_loss = 0.512067,	epoch_test_loss = 0.531519
#
#
# At epoches = 135, epoch_train_loss = 0.512309,	epoch_test_loss = 0.530022
#
#
# At epoches = 136, epoch_train_loss = 0.511620,	epoch_test_loss = 0.530232
#
#
# At epoches = 137, epoch_train_loss = 0.511244,	epoch_test_loss = 0.531016
#
#
# At epoches = 138, epoch_train_loss = 0.511405,	epoch_test_loss = 0.528137
#
#
# At epoches = 139, epoch_train_loss = 0.511653,	epoch_test_loss = 0.526499
#
#
# At epoches = 140, epoch_train_loss = 0.510915,	epoch_test_loss = 0.535762
#
#
# At epoches = 141, epoch_train_loss = 0.511861,	epoch_test_loss = 0.529652
#
#
# At epoches = 142, epoch_train_loss = 0.510864,	epoch_test_loss = 0.530642
#
#
# At epoches = 143, epoch_train_loss = 0.512065,	epoch_test_loss = 0.539453
#
#
# At epoches = 144, epoch_train_loss = 0.510551,	epoch_test_loss = 0.523228
#
#
# At epoches = 145, epoch_train_loss = 0.510262,	epoch_test_loss = 0.534874
#
#
# At epoches = 146, epoch_train_loss = 0.511356,	epoch_test_loss = 0.529213
#
#
# At epoches = 147, epoch_train_loss = 0.511439,	epoch_test_loss = 0.530026
#
#
# At epoches = 148, epoch_train_loss = 0.510029,	epoch_test_loss = 0.537401
#
#
# At epoches = 149, epoch_train_loss = 0.511105,	epoch_test_loss = 0.522565
#
#
# At epoches = 150, epoch_train_loss = 0.511213,	epoch_test_loss = 0.522373
#
#
# At epoches = 151, epoch_train_loss = 0.509044,	epoch_test_loss = 0.546143
#
#
# At epoches = 152, epoch_train_loss = 0.511811,	epoch_test_loss = 0.535132
#
#
# At epoches = 153, epoch_train_loss = 0.510251,	epoch_test_loss = 0.535042
#
#
# At epoches = 154, epoch_train_loss = 0.510381,	epoch_test_loss = 0.518429
#
#
# At epoches = 155, epoch_train_loss = 0.510551,	epoch_test_loss = 0.534291
#
#
# At epoches = 156, epoch_train_loss = 0.509758,	epoch_test_loss = 0.519185
#
#
# At epoches = 157, epoch_train_loss = 0.510246,	epoch_test_loss = 0.533445
#
#
# At epoches = 158, epoch_train_loss = 0.509448,	epoch_test_loss = 0.542468
#
#
# At epoches = 159, epoch_train_loss = 0.510264,	epoch_test_loss = 0.535246
#
#
# At epoches = 160, epoch_train_loss = 0.510460,	epoch_test_loss = 0.533058
#
#
# At epoches = 161, epoch_train_loss = 0.509593,	epoch_test_loss = 0.524568
#
#
# At epoches = 162, epoch_train_loss = 0.509922,	epoch_test_loss = 0.541079
#
#
# At epoches = 163, epoch_train_loss = 0.509867,	epoch_test_loss = 0.530413
#
#
# At epoches = 164, epoch_train_loss = 0.509987,	epoch_test_loss = 0.540248
#
#
# At epoches = 165, epoch_train_loss = 0.509854,	epoch_test_loss = 0.526358
#
#
# At epoches = 166, epoch_train_loss = 0.509637,	epoch_test_loss = 0.531968
#
#
# At epoches = 167, epoch_train_loss = 0.509430,	epoch_test_loss = 0.533989
#
#
# At epoches = 168, epoch_train_loss = 0.508823,	epoch_test_loss = 0.540264
#
#
# At epoches = 169, epoch_train_loss = 0.509439,	epoch_test_loss = 0.529750
#
#
# At epoches = 170, epoch_train_loss = 0.510391,	epoch_test_loss = 0.529007
#
#
# At epoches = 171, epoch_train_loss = 0.508131,	epoch_test_loss = 0.544364
#
#
# At epoches = 172, epoch_train_loss = 0.510388,	epoch_test_loss = 0.532910
#
#
# At epoches = 173, epoch_train_loss = 0.507939,	epoch_test_loss = 0.534477
# ...
#
# At epoches = 242, epoch_train_loss = 0.506224,	epoch_test_loss = 0.531698
#
#
# At epoches = 243, epoch_train_loss = 0.506766,	epoch_test_loss = 0.531561
#
#
# At epoches = 244, epoch_train_loss = 0.506597,	epoch_test_loss = 0.528297
#
#
# At epoches = 245, epoch_train_loss = 0.505899,	epoch_test_loss = 0.528128
#
#
# At epoches = 246, epoch_train_loss = 0.506416,	epoch_test_loss = 0.535150
#
#
# At epoches = 247, epoch_train_loss = 0.506164,	epoch_test_loss = 0.536158
#
#
# At epoches = 248, epoch_train_loss = 0.506435,	epoch_test_loss = 0.528366
#
#
# At epoches = 249, epoch_train_loss = 0.506446,	epoch_test_loss = 0.531899
#
#
# At epoches = 250, epoch_train_loss = 0.506327,	epoch_test_loss = 0.526511
#
#
# At epoches = 251, epoch_train_loss = 0.506826,	epoch_test_loss = 0.527730
#
#
# At epoches = 252, epoch_train_loss = 0.506029,	epoch_test_loss = 0.534134
#
#
# At epoches = 253, epoch_train_loss = 0.506637,	epoch_test_loss = 0.520971
#
#
# At epoches = 254, epoch_train_loss = 0.505896,	epoch_test_loss = 0.520883
#
#
# At epoches = 255, epoch_train_loss = 0.506409,	epoch_test_loss = 0.520097
#
#
# At epoches = 256, epoch_train_loss = 0.506313,	epoch_test_loss = 0.523827
#
#
# At epoches = 257, epoch_train_loss = 0.506181,	epoch_test_loss = 0.521799
#
#
# At epoches = 258, epoch_train_loss = 0.506503,	epoch_test_loss = 0.521149
#
#
# At epoches = 259, epoch_train_loss = 0.506221,	epoch_test_loss = 0.536285
#
#
# At epoches = 260, epoch_train_loss = 0.506124,	epoch_test_loss = 0.527363
#
#
# At epoches = 261, epoch_train_loss = 0.506316,	epoch_test_loss = 0.531971
#
#
# At epoches = 262, epoch_train_loss = 0.505910,	epoch_test_loss = 0.539109
#
#
# At epoches = 263, epoch_train_loss = 0.506239,	epoch_test_loss = 0.532282
#
#
# At epoches = 264, epoch_train_loss = 0.505582,	epoch_test_loss = 0.535174
#
#
# At epoches = 265, epoch_train_loss = 0.506524,	epoch_test_loss = 0.534362
#
#
# At epoches = 266, epoch_train_loss = 0.505836,	epoch_test_loss = 0.532159
#
#
# At epoches = 267, epoch_train_loss = 0.506150,	epoch_test_loss = 0.533995
#
#
# At epoches = 268, epoch_train_loss = 0.505943,	epoch_test_loss = 0.533089
#
#
# At epoches = 269, epoch_train_loss = 0.505881,	epoch_test_loss = 0.517790
#
#
# At epoches = 270, epoch_train_loss = 0.505855,	epoch_test_loss = 0.534281
#
#
# At epoches = 271, epoch_train_loss = 0.505683,	epoch_test_loss = 0.530921
#
#
# At epoches = 272, epoch_train_loss = 0.506443,	epoch_test_loss = 0.535873
#
#
# At epoches = 273, epoch_train_loss = 0.506172,	epoch_test_loss = 0.529381
#
#
# At epoches = 274, epoch_train_loss = 0.506145,	epoch_test_loss = 0.533696
#
#
# At epoches = 275, epoch_train_loss = 0.505484,	epoch_test_loss = 0.523508
#
#
# At epoches = 276, epoch_train_loss = 0.505987,	epoch_test_loss = 0.531933
#
#
# At epoches = 277, epoch_train_loss = 0.504958,	epoch_test_loss = 0.538685
#
#
# At epoches = 278, epoch_train_loss = 0.505738,	epoch_test_loss = 0.530335
#
#
# At epoches = 279, epoch_train_loss = 0.506243,	epoch_test_loss = 0.526911
#
#
# At epoches = 280, epoch_train_loss = 0.505839,	epoch_test_loss = 0.527595
#
#
# At epoches = 281, epoch_train_loss = 0.505632,	epoch_test_loss = 0.528084
#
#
# At epoches = 282, epoch_train_loss = 0.506247,	epoch_test_loss = 0.526700
#
#
# At epoches = 283, epoch_train_loss = 0.505648,	epoch_test_loss = 0.536419
#
#
# At epoches = 284, epoch_train_loss = 0.505664,	epoch_test_loss = 0.527696
#
#
# At epoches = 285, epoch_train_loss = 0.505797,	epoch_test_loss = 0.523684
#
#
# At epoches = 286, epoch_train_loss = 0.505416,	epoch_test_loss = 0.533071
#
#
# At epoches = 287, epoch_train_loss = 0.506094,	epoch_test_loss = 0.532005
#
#
# At epoches = 288, epoch_train_loss = 0.505308,	epoch_test_loss = 0.532035
#
#
# At epoches = 289, epoch_train_loss = 0.505938,	epoch_test_loss = 0.519164
#
#
# At epoches = 290, epoch_train_loss = 0.504357,	epoch_test_loss = 0.536560
#
#
# At epoches = 291, epoch_train_loss = 0.505810,	epoch_test_loss = 0.536930
#
#
# At epoches = 292, epoch_train_loss = 0.505878,	epoch_test_loss = 0.534836
#
#
# At epoches = 293, epoch_train_loss = 0.505374,	epoch_test_loss = 0.520785
#
#
# At epoches = 294, epoch_train_loss = 0.505349,	epoch_test_loss = 0.528301
#
#
# At epoches = 295, epoch_train_loss = 0.505996,	epoch_test_loss = 0.522659
#
#
# At epoches = 296, epoch_train_loss = 0.505489,	epoch_test_loss = 0.522711
#
#
# At epoches = 297, epoch_train_loss = 0.505100,	epoch_test_loss = 0.526967
#
#
# At epoches = 298, epoch_train_loss = 0.504905,	epoch_test_loss = 0.543813
#
#
# At epoches = 299, epoch_train_loss = 0.505110,	epoch_test_loss = 0.527458
# Finished Training

# %%
train_outputs = model(x_train)
test_outputs = model(x_test)
train_tsne_embeds = tsne.fit_transform(train_outputs.cpu().detach().numpy())
test_tsne_embeds = tsne.fit_transform(test_outputs.cpu().detach().numpy())

scatter(train_tsne_embeds, y_train.cpu().numpy(), subtitle=f'online TNN distribution (train set)', dataset='CIFAR10')
scatter(test_tsne_embeds, y_test.cpu().numpy(), subtitle=f'online TNN distribution (test set)', dataset='CIFAR10')
